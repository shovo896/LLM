# %%
import os

os.environ["GROQ_API_KEY"] = "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"
print("GROQ_API_KEY loaded for this notebook session.")
# Out:
# GROQ_API_KEY loaded for this notebook session.

# %%
from langchain_core.prompts import PromptTemplate

template = """I want you act as a phd holder in computer science. I will ask you questions and you 
will answer them as if you were a phd holder in computer science. Do not write explanations. Only answer the question.
My first question is {question}"""

prompt = PromptTemplate(
    input_variables=["question"],
    template=template,
)
prompt.format(question="What is the difference between a list and a tuple in Python?")
# Out:
# 'I want you act as a phd holder in computer science. I will ask you questions and you \nwill answer them as if you were a phd holder in computer science. Do not write explanations. Only answer the question.\nMy first question is What is the difference between a list and a tuple in Python?'

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0.9)
chain = prompt | llm

response = chain.invoke({"question": "What is the difference between a list and a tuple in Python?"})
response.content
# Out:
# 'In Python, a list is a dynamic, mutable, and ordered collection of elements, whereas a tuple is an immutable, ordered collection of elements.'

# %%
from langchain.chains import LLMChain

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0.9)
chain1=LLMChain(prompt=prompt, llm=llm)

# %%
chain1.run("What is the difference between a list and a tuple in Python?")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# ...

# %%
## build a code generator that takes a description of a function and generates the code for it.
from langchain import PromptTemplate
code_template = """I want you to act as a code generator. I will describe a function and you will generate the code for it.
My first description is {description}"""
language = "Python"
code_prompt = PromptTemplate(
    input_variables=["description"],
    template=code_template,
)

code_prompt.format(description="a function that takes a list of numbers and returns the sum of the numbers in the list.")
# Out:
# 'I want you to act as a code generator. I will describe a function and you will generate the code for it.\nMy first description is a function that takes a list of numbers and returns the sum of the numbers in the list.'

# %%
chain2 = code_prompt | llm
chain2({
    'sentence': "a function that takes a list of numbers and returns the sum of the numbers in the list."
    ,'target_language':'python'
    
})
response2 = chain2.invoke({"description": "a function that takes a list of numbers and returns the sum of the numbers in the list."})
response2.content
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 chain2 = code_prompt | llm
# ----> 2 chain2({
#       3     'sentence': "a function that takes a list of numbers and returns the sum of the numbers in the list."
#       4     ,'target_language':'python'
#       5
#       6 })
#       7 response2 = chain2.invoke({"description": "a function that takes a list of numbers and returns the sum of the numbers in the list."})
#       8 response2.content
#
# TypeError: 'RunnableSequence' object is not callable
