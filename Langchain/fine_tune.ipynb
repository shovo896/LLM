# %%
! pip install -q -U google-genai
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pathlib 
import textwrap
from google import genai
from IPython.display import Markdown, display

# %%
def to_markdown(text):
    return Markdown(textwrap.dedent(text))

# %%
import os 
os.environ["GOOGLE_API_KEY"] = "AIzaSyBFYSz9c79Ka4buI7oZppV2DfF8Mo8EES9U0"

# %%
client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

# %% [markdown]
# list models

# %%
for m in client.models.list():
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview

# %%
model=client.models.get(model="gemini-2.5-flash")

# %%
model
# Out:
# Model(
#   description='Stable version of Gemini 2.5 Flash, our mid-size multimodal model that supports up to 1 million tokens, released in June of 2025.',
#   display_name='Gemini 2.5 Flash',
#   input_token_limit=1048576,
#   max_temperature=2.0,
#   name='models/gemini-2.5-flash',
#   output_token_limit=65536,
#   supported_actions=[
#     'generateContent',
#     'countTokens',
#     'createCachedContent',
#     'batchGenerateContent',
#   ],
#   temperature=1.0,
#   thinking=True,
#   top_k=64,
#   top_p=0.95,
#   tuned_model_info=TunedModelInfo(),
#   version='001'
# )

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="what is the meaning of life?",
)
print(response.text)
# Out:
# That is perhaps the most profound and enduring question humanity has ever asked, and the beautiful, frustrating truth is that there is no single, universally agreed-upon answer.
#
# Instead, the "meaning of life" is something that has been explored through countless lenses across history, philosophy, religion, science, and individual experience. Here are some of the most common perspectives:
#
# 1.  **No Inherent Meaning (Existentialism/Absurdism):**
#     *   **Core Idea:** Life doesn't come with a pre-written purpose or meaning. We are born into an indifferent universe, and it's up to us to create our own meaning.
#     *   **Implication:** This can be seen as either terrifying (nihilism) or incredibly liberating (existentialism). We are free to define our values, passions, and purposes.
#     *   **Thinkers:** Jean-Paul Sartre, Albert Camus.
#
# 2.  **Divinely Ordained Meaning (Religion/Spirituality):**
#     *   **Core Idea:** The meaning of life is given by a higher power, God, or universal spiritual principles. Our purpose is to fulfill a divine plan, achieve salvation, enlightenment, or live according to sacred texts and traditions.
#     *   **Implication:** Provides comfort, moral guidance, and a sense of belonging to something larger than oneself.
#     *   **Examples:** Fulfilling God's will in Christianity, achieving Nirvana in Buddhism, performing dharma in Hinduism.
#
# 3.  **Meaning in Connection, Contribution, and Experience (Humanism/Pragmatism):**
#     *   **Core Idea:** Meaning is found in the human experience itself – in our relationships, our capacity for love, compassion, creativity, and our ability to make a positive impact on the world.
#     *   **Implication:** Focuses on human flourishing, ethical action, self-actualization, and the pursuit of happiness and fulfillment.
#     *   **Examples:**
#         *   **Love and Relationships:** Deep connections with family, friends, and romantic partners.
#         *   **Contribution and Service:** Making a difference in your community, through work, volunteering, or activism.
#         *   **Growth and Learning:** Continual self-improvement, understanding the world, acquiring knowledge and skills.
#         *   **Joy and Aesthetic Appreciation:** Experiencing beauty, art, music, nature, and simple pleasures.
#         *   **Purposeful Work/Passions:** Engaging in activities that you find inherently rewarding and challenging.
#
# 4.  **Biological/Evolutionary Purpose:**
#     *   **Core Idea:** From a purely biological perspective, the "purpose" of life is to survive, reproduce, and pass on genes to the next generation.
#     *   **Implication:** While this describes a fundamental biological function, most people don't equate it with the *meaning* of their individual human existence in a philosophical sense.
#
# **Ultimately, the meaning of life is highly personal.**
#
# It's less about finding a definitive answer that applies to everyone and more about **the personal journey of defining what makes your life feel significant, worthwhile, and fulfilling.**
#
# *   What makes you feel alive?
# *   What values do you hold dear?
# *   What brings you joy?
# *   What problems do you want to solve?
# *   What legacy do you want to leave?
#
# The meaning of life isn't a fixed destination, but often an ongoing exploration that can evolve as you grow, learn, and experience different phases of your existence. And perhaps, in that very search, a significant part of its meaning lies.
