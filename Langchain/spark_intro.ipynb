# %%
# !pip install -q pyspark
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-17.0.20.101-hotspot"
os.environ["PATH"] = os.environ["JAVA_HOME"] + r"\bin;" + os.environ["PATH"]

from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .master("local[*]")
    .appName("Intro to PySpark")
    .getOrCreate()
)

print(spark.version)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[35], line 12
#       8 spark = (
#       9     SparkSession.builder
#      10     .master("local[*]")
#      11     .appName("Intro to PySpark")
# ---> 12     .getOrCreate()
#      13 )
#      14
#      15 print(spark.version)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\sql\session.py:564, in SparkSession.Builder.getOrCreate(self)
#     562     session = SparkSession(sc, options=self._options)
#     563 else:
# --> 564     module = SparkSession._get_j_spark_session_module(session._jvm)
#     565     module.applyModifiableSettings(session._jsparkSession, self._options)
#     566 return session
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\sql\session.py:697, in SparkSession._get_j_spark_session_module(jvm)
#     695 @staticmethod
#     696 def _get_j_spark_session_module(jvm: "JVMView") -> "JavaObject":
# --> 697     return getattr(getattr(jvm, "org.apache.spark.sql.classic.SparkSession$"), "MODULE$")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)   1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
from sklearn.datasets import load_breast_cancer 
import pandas as pd 
data = load_breast_cancer()
pdf = pd.DataFrame(data.data,columns=data.feature_names)
pdf.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
df = spark.createDataFrame(pdf)    
df.show(5)
# Out:
# C:\Users\Shuvo\AppData\Roaming\Python\Python313\site-packages\pyspark\sql\pandas\conversion.py:659: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# C:\Users\Shuvo\AppData\Roaming\Python\Python313\site-packages\pyspark\sql\pandas\conversion.py:936: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# C:\Users\Shuvo\AppData\Roaming\Python\Python313\site-packages\pyspark\sql\pandas\conversion.py:687: UserWarning: createDataFrame attempted Arrow optimization because 'spark.sql.execution.arrow.pyspark.enabled' is set to true; however, failed by the reason below:
#   [PACKAGE_NOT_INSTALLED] PyArrow >= 18.0.0 must be installed; however, it was not found.
# Attempting non-optimization as 'spark.sql.execution.arrow.pyspark.fallback.enabled' is set to true.
#   warn(msg)
# +-----------+------------+--------------+---------+---------------+----------------+--------------+-------------------+-------------+----------------------+------------+-------------+---------------+----------+----------------+-----------------+---------------+--------------------+--------------+-----------------------+------------+-------------+---------------+----------+----------------+-----------------+---------------+--------------------+--------------+-----------------------+
# |mean radius|mean texture|mean perimeter|mean area|mean smoothness|mean compactness|mean concavity|mean concave points|mean symmetry|mean fractal dimension|radius error|texture error|perimeter error|area error|smoothness error|compactness error|concavity error|concave points error|symmetry error|fractal dimension error|worst radius|worst texture|worst perimeter|worst area|worst smoothness|worst compactness|worst concavity|worst concave points|worst symmetry|worst fractal dimension|
# +-----------+------------+--------------+---------+---------------+----------------+--------------+-------------------+-------------+----------------------+------------+-------------+---------------+----------+----------------+-----------------+---------------+--------------------+--------------+-----------------------+------------+-------------+---------------+----------+----------------+-----------------+---------------+--------------------+--------------+-----------------------+
# |      17.99|       10.38|         122.8|   1001.0|         0.1184|          0.2776|        0.3001|             0.1471|       0.2419|               0.07871|       1.095|       0.9053|          8.589|     153.4|        0.006399|          0.04904|        0.05373|             0.01587|       0.03003|               0.006193|       25.38|        17.33|          184.6|    2019.0|          0.1622|           0.6656|         0.7119|              0.2654|        0.4601|                 0.1189|
# |      20.57|       17.77|         132.9|   1326.0|        0.08474|         0.07864|        0.0869|            0.07017|       0.1812|               0.05667|      0.5435|       0.7339|          3.398|     74.08|        0.005225|          0.01308|         0.0186|              0.0134|       0.01389|               0.003532|       24.99|        23.41|          158.8|    1956.0|          0.1238|           0.1866|         0.2416|               0.186|         0.275|                0.08902|
# |      19.69|       21.25|         130.0|   1203.0|         0.1096|          0.1599|        0.1974|             0.1279|       0.2069|               0.05999|      0.7456|       0.7869|          4.585|     94.03|         0.00615|          0.04006|        0.03832|             0.02058|        0.0225|               0.004571|       23.57|        25.53|          152.5|    1709.0|          0.1444|           0.4245|         0.4504|               0.243|        0.3613|                0.08758|
# |      11.42|       20.38|         77.58|    386.1|         0.1425|          0.2839|        0.2414|             0.1052|       0.2597|               0.09744|      0.4956|        1.156|          3.445|     27.23|         0.00911|          0.07458|        0.05661|             0.01867|       0.05963|               0.009208|       14.91|         26.5|          98.87|     567.7|          0.2098|           0.8663|         0.6869|              0.2575|        0.6638|                  0.173|
# |      20.29|       14.34|         135.1|   1297.0|         0.1003|          0.1328|         0.198|             0.1043|       0.1809|               0.05883|      0.7572|       0.7813|          5.438|     94.44|         0.01149|          0.02461|        0.05688|             0.01885|       0.01756|               0.005115|       22.54|        16.67|          152.2|    1575.0|          0.1374|            0.205|            0.4|              0.1625|        0.2364|                0.07678|
# +-----------+------------+--------------+---------+---------------+----------------+--------------+-------------------+-------------+----------------------+------------+-------------+---------------+----------+----------------+-----------------+---------------+--------------------+--------------+-----------------------+------------+-------------+---------------+----------+----------------+-----------------+---------------+--------------------+--------------+-----------------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- mean radius: double (nullable = true)
#  |-- mean texture: double (nullable = true)
#  |-- mean perimeter: double (nullable = true)
#  |-- mean area: double (nullable = true)
#  |-- mean smoothness: double (nullable = true)
#  |-- mean compactness: double (nullable = true)
#  |-- mean concavity: double (nullable = true)
#  |-- mean concave points: double (nullable = true)
#  |-- mean symmetry: double (nullable = true)
#  |-- mean fractal dimension: double (nullable = true)
#  |-- radius error: double (nullable = true)
#  |-- texture error: double (nullable = true)
#  |-- perimeter error: double (nullable = true)
#  |-- area error: double (nullable = true)
#  |-- smoothness error: double (nullable = true)
#  |-- compactness error: double (nullable = true)
#  |-- concavity error: double (nullable = true)
#  |-- concave points error: double (nullable = true)
#  |-- symmetry error: double (nullable = true)
#  |-- fractal dimension error: double (nullable = true)
#  |-- worst radius: double (nullable = true)
#  |-- worst texture: double (nullable = true)
#  |-- worst perimeter: double (nullable = true)
#  |-- worst area: double (nullable = true)
#  |-- worst smoothness: double (nullable = true)
#  |-- worst compactness: double (nullable = true)
#  |-- worst concavity: double (nullable = true)
#  |-- worst concave points: double (nullable = true)
#  |-- worst symmetry: double (nullable = true)
#  |-- worst fractal dimension: double (nullable = true)

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer(as_frame=True)

pdf = data.frame.rename(columns={"target": "label"})

df = spark.createDataFrame(pdf)

df.printSchema()
df.groupBy("label").count().show()
# Out:
# C:\Users\Shuvo\AppData\Roaming\Python\Python313\site-packages\pyspark\sql\pandas\conversion.py:659: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# C:\Users\Shuvo\AppData\Roaming\Python\Python313\site-packages\pyspark\sql\pandas\conversion.py:936: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# C:\Users\Shuvo\AppData\Roaming\Python\Python313\site-packages\pyspark\sql\pandas\conversion.py:687: UserWarning: createDataFrame attempted Arrow optimization because 'spark.sql.execution.arrow.pyspark.enabled' is set to true; however, failed by the reason below:
#   [PACKAGE_NOT_INSTALLED] PyArrow >= 18.0.0 must be installed; however, it was not found.
# Attempting non-optimization as 'spark.sql.execution.arrow.pyspark.fallback.enabled' is set to true.
#   warn(msg)
# root
#  |-- mean radius: double (nullable = true)
#  |-- mean texture: double (nullable = true)
#  |-- mean perimeter: double (nullable = true)
#  |-- mean area: double (nullable = true)
#  |-- mean smoothness: double (nullable = true)
#  |-- mean compactness: double (nullable = true)
#  |-- mean concavity: double (nullable = true)
#  |-- mean concave points: double (nullable = true)
#  |-- mean symmetry: double (nullable = true)
#  |-- mean fractal dimension: double (nullable = true)
#  |-- radius error: double (nullable = true)
#  |-- texture error: double (nullable = true)
#  |-- perimeter error: double (nullable = true)
#  |-- area error: double (nullable = true)
#  |-- smoothness error: double (nullable = true)
#  |-- compactness error: double (nullable = true)
#  |-- concavity error: double (nullable = true)
#  |-- concave points error: double (nullable = true)
#  |-- symmetry error: double (nullable = true)
#  |-- fractal dimension error: double (nullable = true)
#  |-- worst radius: double (nullable = true)
#  |-- worst texture: double (nullable = true)
#  |-- worst perimeter: double (nullable = true)
#  |-- worst area: double (nullable = true)
#  |-- worst smoothness: double (nullable = true)
#  |-- worst compactness: double (nullable = true)
#  |-- worst concavity: double (nullable = true)
#  |-- worst concave points: double (nullable = true)
#  |-- worst symmetry: double (nullable = true)
#  |-- worst fractal dimension: double (nullable = true)
#  |-- label: long (nullable = true)
#
# +-----+-----+
# |label|count|
# +-----+-----+
# |    0|  212|
# |    1|  357|
# +-----+-----+

# %%
feature_cols = [col for col in df.columns if col !='label']
print(len(feature_cols))
# Out:
# 30

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features"
)

df_ml = assembler.transform(df)

# %%
df_ml.select("features","label").show(5,truncate= False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |features                                                                                                                                                                                                            |label|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |[17.99,10.38,122.8,1001.0,0.1184,0.2776,0.3001,0.1471,0.2419,0.07871,1.095,0.9053,8.589,153.4,0.006399,0.04904,0.05373,0.01587,0.03003,0.006193,25.38,17.33,184.6,2019.0,0.1622,0.6656,0.7119,0.2654,0.4601,0.1189] |0    |
# |[20.57,17.77,132.9,1326.0,0.08474,0.07864,0.0869,0.07017,0.1812,0.05667,0.5435,0.7339,3.398,74.08,0.005225,0.01308,0.0186,0.0134,0.01389,0.003532,24.99,23.41,158.8,1956.0,0.1238,0.1866,0.2416,0.186,0.275,0.08902]|0    |
# |[19.69,21.25,130.0,1203.0,0.1096,0.1599,0.1974,0.1279,0.2069,0.05999,0.7456,0.7869,4.585,94.03,0.00615,0.04006,0.03832,0.02058,0.0225,0.004571,23.57,25.53,152.5,1709.0,0.1444,0.4245,0.4504,0.243,0.3613,0.08758]  |0    |
# |[11.42,20.38,77.58,386.1,0.1425,0.2839,0.2414,0.1052,0.2597,0.09744,0.4956,1.156,3.445,27.23,0.00911,0.07458,0.05661,0.01867,0.05963,0.009208,14.91,26.5,98.87,567.7,0.2098,0.8663,0.6869,0.2575,0.6638,0.173]      |0    |
# |[20.29,14.34,135.1,1297.0,0.1003,0.1328,0.198,0.1043,0.1809,0.05883,0.7572,0.7813,5.438,94.44,0.01149,0.02461,0.05688,0.01885,0.01756,0.005115,22.54,16.67,152.2,1575.0,0.1374,0.205,0.4,0.1625,0.2364,0.07678]     |0    |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 5 rows

# %%
train_df,test_df =df_ml.randomSplit([0.7,0.3],seed=42)
print(train_df.count(),test_df.count())
# Out:
# 404 165

# %%
from pyspark.ml.classification import LogisticRegression

lr = LogisticRegression(
    featuresCol="features",
    labelCol="label",
    maxIter=100
)

model = lr.fit(train_df)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[33], line 3
#       1 from pyspark.ml.classification import LogisticRegression
#       2
# ----> 3 lr = LogisticRegression(
#       4     featuresCol="features",
#       5     labelCol="label",
#       6     maxIter=100
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\__init__.py:115, in keyword_only.<locals>.wrapper(self, *args, **kwargs)
#     113     raise TypeError("Method %s forces keyword arguments." % func.__name__)
#     114 self._input_kwargs = kwargs
# --> 115 return func(self, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\ml\classification.py:1330, in LogisticRegression.__init__(self, featuresCol, labelCol, predictionCol, maxIter, regParam, elasticNetParam, tol, fitIntercept, threshold, thresholds, probabilityCol, rawPredictionCol, standardization, weightCol, aggregationDepth, family, lowerBoundsOnCoefficients, upperBoundsOnCoefficients, lowerBoundsOnIntercepts, upperBoundsOnIntercepts, maxBlockSizeInMB)
#    1318 """
#    1319 __init__(self, \\*, featuresCol="features", labelCol="label", predictionCol="prediction", \
#    1320          maxIter=100, regParam=0.0, elasticNetParam=0.0, tol=1e-6, fitIntercept=True, \
#    (...)   1327 If the threshold and thresholds Params are both set, they must be equivalent.
#    1328 """
#    1329 super().__init__()
# -> 1330 self._java_obj = self._new_java_obj(
#    1331     "org.apache.spark.ml.classification.LogisticRegression", self.uid
#    1332 )
#    1333 kwargs = self._input_kwargs
#    1334 self.setParams(**kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\ml\util.py:395, in try_remote_return_java_class.<locals>.wrapped(java_class, *args)
#     393     return java_class
#     394 else:
# --> 395     return f(java_class, *args)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\ml\wrapper.py:101, in JavaWrapper._new_java_obj(java_class, *args)
#      99 java_obj = _jvm()
#     100 for name in java_class.split("."):
# --> 101     java_obj = getattr(java_obj, name)
#     102 java_args = [_py2java(sc, arg) for arg in args]
#     103 return java_obj(*java_args)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)   1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
predictions= model.transform(test_df)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 predictions= model.transform(test_df)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\ml\base.py:258, in Transformer.transform(self, dataset, params)
#     256         return self.copy(params)._transform(dataset)
#     257     else:
# --> 258         return self._transform(dataset)
#     259 else:
#     260     raise TypeError("Params must be a param map but got %s." % type(params))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\ml\util.py:269, in try_remote_transform_relation.<locals>.wrapped(self, dataset)
#     267     return ConnectDataFrame(plan=plan, session=session)
#     268 else:
# --> 269     return f(self, dataset)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\ml\wrapper.py:433, in JavaTransformer._transform(self, dataset)
#     429 @try_remote_transform_relation
#     430 def _transform(self, dataset: DataFrame) -> DataFrame:
#     431     assert self._java_obj is not None
# --> 433     self._transfer_params_to_java()
#     434     return DataFrame(self._java_obj.transform(dataset._jdf), dataset.sparkSession)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\ml\wrapper.py:197, in JavaParams._transfer_params_to_java(self)
#     195         self._java_obj.set(pair)
#     196     if self.hasDefault(param):
# --> 197         pair = self._make_java_param_pair(param, self._defaultParamMap[param])
#     198         pair_defaults.append(pair)
#     199 if len(pair_defaults) > 0:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyspark\ml\wrapper.py:179, in JavaParams._make_java_param_pair(self, param, value)
#     176 assert sc is not None and self._java_obj is not None
#     178 param = self._resolveParam(param)
# --> 179 java_param = self._java_obj.getParam(param.name)
#     180 java_value = _py2java(sc, value)
#     181 return java_param.w(java_value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\java_gateway.py:1361, in JavaMember.__call__(self, *args)
#    1354 args_command, temp_args = self._build_args(*args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
# -> 1361 answer = self.gateway_client.send_command(command)
#    1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)   1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File ~\AppData\Roaming\Python\Python313\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
