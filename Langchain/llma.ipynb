# %%
import os 
open_api_key ="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" 
os.environ["OPENAI_API_KEY"] = open_api_key

# %% [markdown]
# basic prompt summarization

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage,AIMessage,SystemMessage
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#       2 from langchain.schema import HumanMessage,AIMessage,SystemMessage
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (C:\Users\Shuvo\AppData\Roaming\Python\Python313\site-packages\langchain\chat_models\__init__.py)
