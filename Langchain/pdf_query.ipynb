# %%
# %pip install -q langchain
# %pip install -q langchain-groq
# %pip install -q pypdf
# %pip install -q faiss-cpu
# %pip install -q tiktoken
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypdf import PdfReader
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"
os.environ["SERPAPI_API_KEY"] = ""

# %%
Pdfreader=PdfReader("./2010.11929v2.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Pdfreader=PdfReader("./2010.11929v2.pdf")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pypdf/_reader.py:149, in PdfReader.__init__(self, stream, strict, password, root_object_recovery_limit)
#     145 self._page_id2num: Optional[dict[Any, Any]] = None
#     147 self._validated_root: Optional[DictionaryObject] = None
# --> 149 self._initialize_stream(stream)
#     150 self._known_objects: set[tuple[int, int]] = set()
#     152 self._override_encryption = False
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pypdf/_reader.py:168, in PdfReader._initialize_stream(self, stream)
#     166 self._stream_opened = False
#     167 if isinstance(stream, (str, Path)):
# --> 168     with open(stream, "rb") as fh:
#     169         stream = BytesIO(fh.read())
#     170     self._stream_opened = True
#
# FileNotFoundError: [Errno 2] No such file or directory: './2010.11929v2.pdf'
