# %%
# %pip install -q langchain
# %pip install -q langchain-groq
# %pip install -q pypdf
# %pip install -q faiss-cpu
# %pip install -q tiktoken
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypdf import PdfReader
from langchain.embeddings import GroqEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 from pypdf import PdfReader
# ----> 2 from langchain.embeddings import GroqEmbeddings
#       3 from langchain.vectorstores import FAISS
#       4 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ImportError: cannot import name 'GroqEmbeddings' from 'langchain.embeddings' (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/embeddings/__init__.py)
