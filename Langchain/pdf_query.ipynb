# %%
# !pip install langchain 
# !pip install Groq 
# !pip install PyPDF
# !pip install faiss-cpu 
# !pip install tiktoken
# Out:
# /bin/bash: pip: command not found
# /bin/bash: pip: command not found
# /bin/bash: pip: command not found
# /bin/bash: pip: command not found
# /bin/bash: pip: command not found
