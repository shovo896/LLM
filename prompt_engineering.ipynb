# %%
# %pip install --upgrade openai
# Restart the kernel once if `openai` was already imported in this session.

# %%
import os
from getpass import getpass
from openai import OpenAI

api_key = os.getenv("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")
if not api_key:
    api_key = getpass("Enter your OpenAI API key: ").strip()

if not api_key:
    raise RuntimeError("No API key provided.")

os.environ["OPENAI_API_KEY"] = api_key
client = OpenAI(api_key=api_key)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 13
#      10     raise RuntimeError("No API key provided.")
#      12 os.environ["OPENAI_API_KEY"] = api_key
# ---> 13 client = OpenAI(api_key=api_key)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openai/_client.py:106, in OpenAI.__init__(self, api_key, organization, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     103 if base_url is None:
#     104     base_url = f"https://api.openai.com/v1"
# --> 106 super().__init__(
#     107     version=__version__,
#     108     base_url=base_url,
#     109     max_retries=max_retries,
#     110     timeout=timeout,
#     111     http_client=http_client,
#     112     custom_headers=default_headers,
#     113     custom_query=default_query,
# ...
