# %%
# %pip install --upgrade openai
# If this notebook had already imported `openai`, restart the kernel once after this cell.

# %%
import openai
api_key="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"
client = openai.OpenAI(api_key=api_key)
def get_completation(prompt):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content
