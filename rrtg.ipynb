# %%
import numpy as np

arr = np.array([[1, 2, 3], [4, 5, 6]])
flattened_arr = arr.flatten()
print("Flattened array:")
print(flattened_arr)
# Out:
# Flattened array:
# [1 2 3 4 5 6]
# Flattened array:
# [1 2 3 4 5 6]
